# %%
from craigslist import *
from util import *
#from StringIO import StringIO
from IPython.display import Image
from IPython.core.display import HTML 
from IPython.display import display

import urllib




# get the collection of desired data
houses = CraigslistForSale(
    site="boston"
)


result = houses.get_results(limit=10)

next(result)
datam = next(result)
print(datam)

# get image urls
urls = get_img_urls(datam)
print(urls)

#turl = urls[0]
#print(turl)
#Image(url=turl, format="jpg")


# download images
for URL in urls:
    
    #print(URL)
    
    # display image
    display(Image(URL))
    

    '''
    img = Image.open(
        StringIO(urllib.urlopen(url).read())
    )

    '''
    
    '''
    urllib.urlretrieve(
        url,
        "./images/" + url.rsplit('/', 1)[-1]
    )
    '''
#Image("https://images.craigslist.org/00P0P_ezn7TlRWZ6q_600x450.jpg")
#Image("https://images.craigslist.org/01212_cdzx2AGa6cI_600x450.jpg")
# Out:
# {'url': 'http://boston.craigslist.org/nwb/spo/5814132437.html', 'has_map': True, 'price': '$25', 'name': 'Metal Frame Backpack Large Green Boy Scouts Hiking Camping', 'where': 'By Kimball Farm in Westford', 'datetime': '2016-10-07 16:07', 'id': '5814132437', 'geotag': None, 'has_image': True}
# ['https://images.craigslist.org/00Q0Q_9wRJMlVCi2j_600x450.jpg', 'https://images.craigslist.org/00j0j_bMsknMyxisf_600x450.jpg', 'https://images.craigslist.org/00a0a_eTXKiIPryU9_600x450.jpg', 'https://images.craigslist.org/01313_2OfQOmbvf19_600x450.jpg']
